# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("E:\python practice\heart_failure_clinical_records_dataset (1).csv")
dataset.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %%
dataset.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
dataset=dataset.dropna(axis=0)

# %%
dataset
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.pairplot(data=dataset,x_vars=['ejection_fraction', 'platelets','age', 'anaemia', 'creatinine_phosphokinase', 'diabetes'],y_vars="DEATH_EVENT")
plt.show()

# %%
x = dataset[['time','ejection_fraction','serum_creatinine']]
y = dataset["DEATH_EVENT"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
x_train.shape
# Out:
# (239, 3)

# %%
y_train.shape
# Out:
# (239,)

# %% [markdown]
# # # SVM Clasifier

# %%
from sklearn.svm import SVC 
SVA = SVC(kernel = 'rbf' ,random_state=0) #Mapping data into a high dimesional space is called kernalling.
#by default the kernel will be rbf and by default the random state will be 0.
SVA.fit(x_train, y_train)
# Out:
# SVC(random_state=0)

# %%
Y_pred = SVA.predict(x_test)

# %%
CM=confusion_matrix(y_test,Y_pred)

# %%
CM
# Out:
# array([[43,  0],
#        [ 6, 11]], dtype=int64)

# %%
sns.heatmap(CM_1,annot=True)
# Out:
# <AxesSubplot:>

# %%
print("{}%".format(accuracy_score(y_test,Y_pred)*100))
# Out:
# 90.0%

# %%
print(classification_report(y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93        43
#            1       1.00      0.65      0.79        17
#
#     accuracy                           0.90        60
#    macro avg       0.94      0.82      0.86        60
# weighted avg       0.91      0.90      0.89        60
